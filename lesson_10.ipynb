# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %%
df = pd.DataFrame(
    [ ['Jan',58,42,74,22,2.05],
    ['Feb',61,45,78,26,3.02],
    ['Mar',65,48,84,25,2.34],
    ['Apr',67,50,92,28,1.02],
    ['May',71,53,98,35,0.48],
    ['Jun',75,56,107,41,0.11],
    ['Jul',77,58,105,44,0.0],
    ['Aug',77,59,102,43,0.03],
    ['Sep',77,57,103,40,0.17],
    ['Oct',73,54,96,34,0.81],
    ['Nov',64,48,84,30,1.7],
    ['Dec',58,None,None,21,2.56],
    ['Dec',58,42,73,21,2.56] ],
    columns = ['month','avg_high','avg_low','record_high','record_low','avg_precipitation'])

# %%
df
# Out:
#    month  avg_high  avg_low  record_high  record_low  avg_precipitation
# 0    Jan        58     42.0         74.0          22               2.05
# 1    Feb        61     45.0         78.0          26               3.02
# 2    Mar        65     48.0         84.0          25               2.34
# 3    Apr        67     50.0         92.0          28               1.02
# 4    May        71     53.0         98.0          35               0.48
# 5    Jun        75     56.0        107.0          41               0.11
# 6    Jul        77     58.0        105.0          44               0.00
# 7    Aug        77     59.0        102.0          43               0.03
# 8    Sep        77     57.0        103.0          40               0.17
# 9    Oct        73     54.0         96.0          34               0.81
# 10   Nov        64     48.0         84.0          30               1.70
# 11   Dec        58      NaN          NaN          21               2.56
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   month              13 non-null     object
#  1   avg_high           13 non-null     int64
#  2   avg_low            12 non-null     float64
#  3   record_high        12 non-null     float64
#  4   record_low         13 non-null     int64
#  5   avg_precipitation  13 non-null     float64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 752.0+ bytes

# %%
list( df.columns )
# Out:
# ['month',
#  'avg_high',
#  'avg_low',
#  'record_high',
#  'record_low',
#  'avg_precipitation']

# %% [markdown]
# ## sorting values

# %%
df.sort_values( 'record_high' )
# Out:
#    month  avg_high  avg_low  record_high  record_low  avg_precipitation
# 12   Dec        58     42.0         73.0          21               2.56
# 0    Jan        58     42.0         74.0          22               2.05
# 1    Feb        61     45.0         78.0          26               3.02
# 2    Mar        65     48.0         84.0          25               2.34
# 10   Nov        64     48.0         84.0          30               1.70
# 3    Apr        67     50.0         92.0          28               1.02
# 9    Oct        73     54.0         96.0          34               0.81
# 4    May        71     53.0         98.0          35               0.48
# 7    Aug        77     59.0        102.0          43               0.03
# 8    Sep        77     57.0        103.0          40               0.17
# 6    Jul        77     58.0        105.0          44               0.00
# 5    Jun        75     56.0        107.0          41               0.11
# ...

# %%
df.sort_values( 'record_high', ascending=False )
# Out:
#    month  avg_high  avg_low  record_high  record_low  avg_precipitation
# 5    Jun        75     56.0        107.0          41               0.11
# 6    Jul        77     58.0        105.0          44               0.00
# 8    Sep        77     57.0        103.0          40               0.17
# 7    Aug        77     59.0        102.0          43               0.03
# 4    May        71     53.0         98.0          35               0.48
# 9    Oct        73     54.0         96.0          34               0.81
# 3    Apr        67     50.0         92.0          28               1.02
# 2    Mar        65     48.0         84.0          25               2.34
# 10   Nov        64     48.0         84.0          30               1.70
# 1    Feb        61     45.0         78.0          26               3.02
# 0    Jan        58     42.0         74.0          22               2.05
# 12   Dec        58     42.0         73.0          21               2.56
# ...

# %%
df.sort_values( 'avg_low' )
# Out:
#    month  avg_high  avg_low  record_high  record_low  avg_precipitation
# 0    Jan        58     42.0         74.0          22               2.05
# 12   Dec        58     42.0         73.0          21               2.56
# 1    Feb        61     45.0         78.0          26               3.02
# 2    Mar        65     48.0         84.0          25               2.34
# 10   Nov        64     48.0         84.0          30               1.70
# 3    Apr        67     50.0         92.0          28               1.02
# 4    May        71     53.0         98.0          35               0.48
# 9    Oct        73     54.0         96.0          34               0.81
# 5    Jun        75     56.0        107.0          41               0.11
# 8    Sep        77     57.0        103.0          40               0.17
# 6    Jul        77     58.0        105.0          44               0.00
# 7    Aug        77     59.0        102.0          43               0.03
# ...

# %%
df.sort_values( ['avg_low', 'record_high' ] )
# Out:
#    month  avg_high  avg_low  record_high  record_low  avg_precipitation
# 12   Dec        58     42.0         73.0          21               2.56
# 0    Jan        58     42.0         74.0          22               2.05
# 1    Feb        61     45.0         78.0          26               3.02
# 2    Mar        65     48.0         84.0          25               2.34
# 10   Nov        64     48.0         84.0          30               1.70
# 3    Apr        67     50.0         92.0          28               1.02
# 4    May        71     53.0         98.0          35               0.48
# 9    Oct        73     54.0         96.0          34               0.81
# 5    Jun        75     56.0        107.0          41               0.11
# 8    Sep        77     57.0        103.0          40               0.17
# 6    Jul        77     58.0        105.0          44               0.00
# 7    Aug        77     59.0        102.0          43               0.03
# ...

# %%
df.sort_values( ['avg_low', 'record_high' ], ascending=[True, False ] )
# Out:
#    month  avg_high  avg_low  record_high  record_low  avg_precipitation
# 0    Jan        58     42.0         74.0          22               2.05
# 12   Dec        58     42.0         73.0          21               2.56
# 1    Feb        61     45.0         78.0          26               3.02
# 2    Mar        65     48.0         84.0          25               2.34
# 10   Nov        64     48.0         84.0          30               1.70
# 3    Apr        67     50.0         92.0          28               1.02
# 4    May        71     53.0         98.0          35               0.48
# 9    Oct        73     54.0         96.0          34               0.81
# 5    Jun        75     56.0        107.0          41               0.11
# 8    Sep        77     57.0        103.0          40               0.17
# 6    Jul        77     58.0        105.0          44               0.00
# 7    Aug        77     59.0        102.0          43               0.03
# ...

# %% [markdown]
# ## types and taking specific rows/colomns

# %%
print( type(df) )
print (df[ 'avg_precipitation' ] )
print ( type(df[ 'avg_precipitation' ]) )
# Out:
# <class 'pandas.core.frame.DataFrame'>
# 0     2.05
# 1     3.02
# 2     2.34
# 3     1.02
# 4     0.48
# 5     0.11
# 6     0.00
# 7     0.03
# 8     0.17
# 9     0.81
# 10    1.70
# 11    2.56
# 12    2.56
# Name: avg_precipitation, dtype: float64
# <class 'pandas.core.series.Series'>

# %%
print( df[ ['avg_precipitation', 'record_low'] ] )
print( type( df[ ['avg_precipitation', 'record_low'] ] ) )
# Out:
#     avg_precipitation  record_low
# 0                2.05          22
# 1                3.02          26
# 2                2.34          25
# 3                1.02          28
# 4                0.48          35
# 5                0.11          41
# 6                0.00          44
# 7                0.03          43
# 8                0.17          40
# 9                0.81          34
# 10               1.70          30
# 11               2.56          21
# 12               2.56          21
# <class 'pandas.core.frame.DataFrame'>

# %%
df
# Out:
#    month  avg_high  avg_low  record_high  record_low  avg_precipitation
# 0    Jan        58     42.0         74.0          22               2.05
# 1    Feb        61     45.0         78.0          26               3.02
# 2    Mar        65     48.0         84.0          25               2.34
# 3    Apr        67     50.0         92.0          28               1.02
# 4    May        71     53.0         98.0          35               0.48
# 5    Jun        75     56.0        107.0          41               0.11
# 6    Jul        77     58.0        105.0          44               0.00
# 7    Aug        77     59.0        102.0          43               0.03
# 8    Sep        77     57.0        103.0          40               0.17
# 9    Oct        73     54.0         96.0          34               0.81
# 10   Nov        64     48.0         84.0          30               1.70
# 11   Dec        58      NaN          NaN          21               2.56
# ...

# %% [markdown]
# ## adding new data

# %%
df_2 = df
df_2
# Out:
#    month  avg_high  avg_low  record_high  record_low  avg_precipitation
# 0    Jan        58     42.0         74.0          22               2.05
# 1    Feb        61     45.0         78.0          26               3.02
# 2    Mar        65     48.0         84.0          25               2.34
# 3    Apr        67     50.0         92.0          28               1.02
# 4    May        71     53.0         98.0          35               0.48
# 5    Jun        75     56.0        107.0          41               0.11
# 6    Jul        77     58.0        105.0          44               0.00
# 7    Aug        77     59.0        102.0          43               0.03
# 8    Sep        77     57.0        103.0          40               0.17
# 9    Oct        73     54.0         96.0          34               0.81
# 10   Nov        64     48.0         84.0          30               1.70
# 11   Dec        58      NaN          NaN          21               2.56
# ...

# %%
df_2[ 'new_column' ] = 10
df_2
# Out:
#    month  avg_high  avg_low  record_high  record_low  avg_precipitation  \
# 0    Jan        58     42.0         74.0          22               2.05
# 1    Feb        61     45.0         78.0          26               3.02
# 2    Mar        65     48.0         84.0          25               2.34
# 3    Apr        67     50.0         92.0          28               1.02
# 4    May        71     53.0         98.0          35               0.48
# 5    Jun        75     56.0        107.0          41               0.11
# 6    Jul        77     58.0        105.0          44               0.00
# 7    Aug        77     59.0        102.0          43               0.03
# 8    Sep        77     57.0        103.0          40               0.17
# 9    Oct        73     54.0         96.0          34               0.81
# 10   Nov        64     48.0         84.0          30               1.70
# 11   Dec        58      NaN          NaN          21               2.56
# ...

# %%
df_2[ 'new_column_2' ] = df_2[ 'record_high' ] / df_2[ 'record_low' ]
df_2
# Out:
#    month  avg_high  avg_low  record_high  record_low  avg_precipitation  \
# 0    Jan        58     42.0         74.0          22               2.05
# 1    Feb        61     45.0         78.0          26               3.02
# 2    Mar        65     48.0         84.0          25               2.34
# 3    Apr        67     50.0         92.0          28               1.02
# 4    May        71     53.0         98.0          35               0.48
# 5    Jun        75     56.0        107.0          41               0.11
# 6    Jul        77     58.0        105.0          44               0.00
# 7    Aug        77     59.0        102.0          43               0.03
# 8    Sep        77     57.0        103.0          40               0.17
# 9    Oct        73     54.0         96.0          34               0.81
# 10   Nov        64     48.0         84.0          30               1.70
# 11   Dec        58      NaN          NaN          21               2.56
# ...

# %% [markdown]
# ## .loc

# %% [markdown]
# ### taking only rows

# %%
df.loc[ 10 ]
# Out:
# month                 Nov
# avg_high               64
# avg_low              48.0
# record_high          84.0
# record_low             30
# avg_precipitation     1.7
# new_column             10
# new_column_2          2.8
# Name: 10, dtype: object

# %%
df.loc[ 8 ]
# Out:
# month                  Sep
# avg_high                77
# avg_low               57.0
# record_high          103.0
# record_low              40
# avg_precipitation     0.17
# new_column              10
# new_column_2         2.575
# Name: 8, dtype: object

# %%
df.loc[ [8, 10, 5]  ]
# Out:
#    month  avg_high  avg_low  record_high  record_low  avg_precipitation  \
# 8    Sep        77     57.0        103.0          40               0.17
# 10   Nov        64     48.0         84.0          30               1.70
# 5    Jun        75     56.0        107.0          41               0.11
#
#     new_column  new_column_2
# 8           10      2.575000
# 10          10      2.800000
# 5           10      2.609756

# %% [markdown]
# ### taking rows and columns

# %%
df.loc[ [8, 10, 5], 'month'  ]
# Out:
# 8     Sep
# 10    Nov
# 5     Jun
# Name: month, dtype: object

# %%
df.loc[ [8, 10, 5], ['month', 'record_high', 'record_low'] ]
# Out:
#    month  record_high  record_low
# 8    Sep        103.0          40
# 10   Nov         84.0          30
# 5    Jun        107.0          41

# %% [markdown]
# ## .iloc

# %%
df_2 = df_2.sort_values('new_column_2')
df_2
# Out:
#    month  avg_high  avg_low  record_high  record_low  avg_precipitation  \
# 7    Aug        77     59.0        102.0          43               0.03
# 6    Jul        77     58.0        105.0          44               0.00
# 8    Sep        77     57.0        103.0          40               0.17
# 5    Jun        75     56.0        107.0          41               0.11
# 4    May        71     53.0         98.0          35               0.48
# 10   Nov        64     48.0         84.0          30               1.70
# 9    Oct        73     54.0         96.0          34               0.81
# 1    Feb        61     45.0         78.0          26               3.02
# 3    Apr        67     50.0         92.0          28               1.02
# 2    Mar        65     48.0         84.0          25               2.34
# 0    Jan        58     42.0         74.0          22               2.05
# 12   Dec        58     42.0         73.0          21               2.56
# ...

# %%
df_2.loc[ [8, 10, 5], ['month', 'record_high', 'record_low'] ]
# Out:
#    month  record_high  record_low
# 8    Sep        103.0          40
# 10   Nov         84.0          30
# 5    Jun        107.0          41

# %%
# row indexes counting from the top
df_2.iloc[ [8, 10, 5, 0] ]
# Out:
#    month  avg_high  avg_low  record_high  record_low  avg_precipitation  \
# 3    Apr        67     50.0         92.0          28               1.02
# 0    Jan        58     42.0         74.0          22               2.05
# 10   Nov        64     48.0         84.0          30               1.70
# 7    Aug        77     59.0        102.0          43               0.03
#
#     new_column  new_column_2
# 3           10      3.285714
# 0           10      3.363636
# 10          10      2.800000
# 7           10      2.372093

# %%
df_2.iloc[ [8, 10, 5, 0] ][ ['month', 'record_high', 'record_low'] ]
# Out:
#    month  record_high  record_low
# 3    Apr         92.0          28
# 0    Jan         74.0          22
# 10   Nov         84.0          30
# 7    Aug        102.0          43

# %% [markdown]
# ### slicing indexes

# %%
df_2.iloc[ 1:5 ]  # df.iloc[ row_idxs ]
# Out:
#   month  avg_high  avg_low  record_high  record_low  avg_precipitation  \
# 6   Jul        77     58.0        105.0          44               0.00
# 8   Sep        77     57.0        103.0          40               0.17
# 5   Jun        75     56.0        107.0          41               0.11
# 4   May        71     53.0         98.0          35               0.48
#
#    new_column  new_column_2
# 6          10      2.386364
# 8          10      2.575000
# 5          10      2.609756
# 4          10      2.800000

# %%
# df_2.loc[ 1:5 ]
df_2.loc[ range(1,5) ] # df.loc[ row_idxs, column_idxs ]
# Out:
#   month  avg_high  avg_low  record_high  record_low  avg_precipitation  \
# 1   Feb        61     45.0         78.0          26               3.02
# 2   Mar        65     48.0         84.0          25               2.34
# 3   Apr        67     50.0         92.0          28               1.02
# 4   May        71     53.0         98.0          35               0.48
#
#    new_column  new_column_2
# 1          10      3.000000
# 2          10      3.360000
# 3          10      3.285714
# 4          10      2.800000

# %% [markdown]
# ## Changing row indexes

# %%
df_2
# Out:
#    month  avg_high  avg_low  record_high  record_low  avg_precipitation  \
# 7    Aug        77     59.0        102.0          43               0.03
# 6    Jul        77     58.0        105.0          44               0.00
# 8    Sep        77     57.0        103.0          40               0.17
# 5    Jun        75     56.0        107.0          41               0.11
# 4    May        71     53.0         98.0          35               0.48
# 10   Nov        64     48.0         84.0          30               1.70
# 9    Oct        73     54.0         96.0          34               0.81
# 1    Feb        61     45.0         78.0          26               3.02
# 3    Apr        67     50.0         92.0          28               1.02
# 2    Mar        65     48.0         84.0          25               2.34
# 0    Jan        58     42.0         74.0          22               2.05
# 12   Dec        58     42.0         73.0          21               2.56
# ...

# %%
df_2.set_index( 'month' )
# Out:
#        avg_high  avg_low  record_high  record_low  avg_precipitation  \
# month
# Aug          77     59.0        102.0          43               0.03
# Jul          77     58.0        105.0          44               0.00
# Sep          77     57.0        103.0          40               0.17
# Jun          75     56.0        107.0          41               0.11
# May          71     53.0         98.0          35               0.48
# Nov          64     48.0         84.0          30               1.70
# Oct          73     54.0         96.0          34               0.81
# Feb          61     45.0         78.0          26               3.02
# Apr          67     50.0         92.0          28               1.02
# Mar          65     48.0         84.0          25               2.34
# Jan          58     42.0         74.0          22               2.05
# Dec          58     42.0         73.0          21               2.56
# ...

# %%
df_2 = df_2.set_index( 'month' )

# %%
# df_2.loc[ 0 ] # error
df_2.loc[ 'Sep' ]
# Out:
# avg_high              77.000
# avg_low               57.000
# record_high          103.000
# record_low            40.000
# avg_precipitation      0.170
# new_column            10.000
# new_column_2           2.575
# Name: Sep, dtype: float64

# %%
df_2.loc[ ['Sep', 'Dec'] ]
# Out:
#        avg_high  avg_low  record_high  record_low  avg_precipitation  \
# month
# Sep          77     57.0        103.0          40               0.17
# Dec          58     42.0         73.0          21               2.56
# Dec          58      NaN          NaN          21               2.56
#
#        new_column  new_column_2
# month
# Sep            10       2.57500
# Dec            10       3.47619
# Dec            10           NaN

# %%
# df_2.iloc[ ['Sep', 'Dec'] ] # error
df_2.iloc[ [0,1] ]
# Out:
#        avg_high  avg_low  record_high  record_low  avg_precipitation  \
# month
# Aug          77     59.0        102.0          43               0.03
# Jul          77     58.0        105.0          44               0.00
#
#        new_column  new_column_2
# month
# Aug            10      2.372093
# Jul            10      2.386364

# %%
df_2.loc[ ['Sep', 'Dec'], ['avg_high', 'avg_low'] ]
# Out:
#        avg_high  avg_low
# month
# Sep          77     57.0
# Dec          58     42.0
# Dec          58      NaN

# %%
df_multiindex = df_2.reset_index().set_index( ['month', 'record_low'] ) # multiindex
df_multiindex
# Out:
#                   avg_high  avg_low  record_high  avg_precipitation  \
# month record_low
# Aug   43                77     59.0        102.0               0.03
# Jul   44                77     58.0        105.0               0.00
# Sep   40                77     57.0        103.0               0.17
# Jun   41                75     56.0        107.0               0.11
# May   35                71     53.0         98.0               0.48
# Nov   30                64     48.0         84.0               1.70
# Oct   34                73     54.0         96.0               0.81
# Feb   26                61     45.0         78.0               3.02
# Apr   28                67     50.0         92.0               1.02
# Mar   25                65     48.0         84.0               2.34
# Jan   22                58     42.0         74.0               2.05
# Dec   21                58     42.0         73.0               2.56
# ...

# %% [markdown]
# ## drop/fill NaN values

# %%
df_2
# Out:
#        avg_high  avg_low  record_high  record_low  avg_precipitation  \
# month
# Aug          77     59.0        102.0          43               0.03
# Jul          77     58.0        105.0          44               0.00
# Sep          77     57.0        103.0          40               0.17
# Jun          75     56.0        107.0          41               0.11
# May          71     53.0         98.0          35               0.48
# Nov          64     48.0         84.0          30               1.70
# Oct          73     54.0         96.0          34               0.81
# Feb          61     45.0         78.0          26               3.02
# Apr          67     50.0         92.0          28               1.02
# Mar          65     48.0         84.0          25               2.34
# Jan          58     42.0         74.0          22               2.05
# Dec          58     42.0         73.0          21               2.56
# ...

# %%
df_2.dropna()
# Out:
#        avg_high  avg_low  record_high  record_low  avg_precipitation  \
# month
# Aug          77     59.0        102.0          43               0.03
# Jul          77     58.0        105.0          44               0.00
# Sep          77     57.0        103.0          40               0.17
# Jun          75     56.0        107.0          41               0.11
# May          71     53.0         98.0          35               0.48
# Nov          64     48.0         84.0          30               1.70
# Oct          73     54.0         96.0          34               0.81
# Feb          61     45.0         78.0          26               3.02
# Apr          67     50.0         92.0          28               1.02
# Mar          65     48.0         84.0          25               2.34
# Jan          58     42.0         74.0          22               2.05
# Dec          58     42.0         73.0          21               2.56
#
#        new_column  new_column_2
# month
# ...

# %%
df_2.fillna(100)
# Out:
#        avg_high  avg_low  record_high  record_low  avg_precipitation  \
# month
# Aug          77     59.0        102.0          43               0.03
# Jul          77     58.0        105.0          44               0.00
# Sep          77     57.0        103.0          40               0.17
# Jun          75     56.0        107.0          41               0.11
# May          71     53.0         98.0          35               0.48
# Nov          64     48.0         84.0          30               1.70
# Oct          73     54.0         96.0          34               0.81
# Feb          61     45.0         78.0          26               3.02
# Apr          67     50.0         92.0          28               1.02
# Mar          65     48.0         84.0          25               2.34
# Jan          58     42.0         74.0          22               2.05
# Dec          58     42.0         73.0          21               2.56
# ...

# %%
df_2.fillna(method='ffill')
# Out:
#        avg_high  avg_low  record_high  record_low  avg_precipitation  \
# month
# Aug          77     59.0        102.0          43               0.03
# Jul          77     58.0        105.0          44               0.00
# Sep          77     57.0        103.0          40               0.17
# Jun          75     56.0        107.0          41               0.11
# May          71     53.0         98.0          35               0.48
# Nov          64     48.0         84.0          30               1.70
# Oct          73     54.0         96.0          34               0.81
# Feb          61     45.0         78.0          26               3.02
# Apr          67     50.0         92.0          28               1.02
# Mar          65     48.0         84.0          25               2.34
# Jan          58     42.0         74.0          22               2.05
# Dec          58     42.0         73.0          21               2.56
# ...

# %% [markdown]
# ## saving to file

# %%
df_2 = df_2.dropna()
df_2
# Out:
#        avg_high  avg_low  record_high  record_low  avg_precipitation  \
# month
# Aug          77     59.0        102.0          43               0.03
# Jul          77     58.0        105.0          44               0.00
# Sep          77     57.0        103.0          40               0.17
# Jun          75     56.0        107.0          41               0.11
# May          71     53.0         98.0          35               0.48
# Nov          64     48.0         84.0          30               1.70
# Oct          73     54.0         96.0          34               0.81
# Feb          61     45.0         78.0          26               3.02
# Apr          67     50.0         92.0          28               1.02
# Mar          65     48.0         84.0          25               2.34
# Jan          58     42.0         74.0          22               2.05
# Dec          58     42.0         73.0          21               2.56
#
#        new_column  new_column_2
# month
# ...

# %%
df_2.to_csv('weather.csv')

# %%
df = pd.read_csv('LT.csv')
df
# Out:
#            date   home_team  away_team  home_score  away_score  \
# 0    1979-07-20  Kyrgyzstan  Lithuania           0           0
# 1    1979-07-22     Georgia  Lithuania           5           0
# 2    1979-07-24  Azerbaijan  Lithuania           0           1
# 3    1979-07-28   Lithuania    Ukraine           0           2
# 4    1979-07-30      Russia  Lithuania           2           0
# ..          ...         ...        ...         ...         ...
# 362  2019-09-10   Lithuania   Portugal           1           5
# 363  2019-10-11     Ukraine  Lithuania           2           0
# 364  2019-10-11     Ukraine  Lithuania           2           0
# 365  2019-10-14   Lithuania     Serbia           1           2
# 366  2019-10-14   Lithuania     Serbia           1           2
#
#                   tourniment     city       country
# 0                   Friendly   Moscow  Soviet Union
# 1                   Friendly   Moscow  Soviet Union
# ...

# %%
df.describe()
# Out:
#        home_score  away_score
# count  367.000000  367.000000
# mean     1.547684    0.986376
# std      1.349879    1.172233
# min      0.000000    0.000000
# 25%      1.000000    0.000000
# 50%      1.000000    1.000000
# 75%      2.000000    1.000000
# max      5.000000    7.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        367 non-null    object
#  1   home_team   367 non-null    object
#  2   away_team   367 non-null    object
#  3   home_score  367 non-null    int64
#  4   away_score  367 non-null    int64
#  5   tourniment  367 non-null    object
#  6   city        367 non-null    object
#  7   country     367 non-null    object
# dtypes: int64(2), object(6)
# memory usage: 23.1+ KB

# %%
df['date']
# Out:
# 0      1979-07-20
# 1      1979-07-22
# 2      1979-07-24
# 3      1979-07-28
# 4      1979-07-30
#           ...
# 362    2019-09-10
# 363    2019-10-11
# 364    2019-10-11
# 365    2019-10-14
# 366    2019-10-14
# Name: date, Length: 367, dtype: object

# %% [markdown]
# ## row filtering

# %%
df[ df['home_team'] == 'Lithuania' ]
# Out:
#            date  home_team away_team  home_score  away_score  \
# 3    1979-07-28  Lithuania   Ukraine           0           2
# 8    1991-11-15  Lithuania   Estonia           4           1
# 9    1991-11-17  Lithuania    Latvia           1           1
# 17   1992-09-02  Lithuania   Georgia           1           0
# 18   1992-09-23  Lithuania   Denmark           0           0
# ..          ...        ...       ...         ...         ...
# 360  2019-09-07  Lithuania   Ukraine           0           3
# 361  2019-09-10  Lithuania  Portugal           1           5
# 362  2019-09-10  Lithuania  Portugal           1           5
# 365  2019-10-14  Lithuania    Serbia           1           2
# 366  2019-10-14  Lithuania    Serbia           1           2
#
#                        tourniment      city       country
# 3                        Friendly    Moscow  Soviet Union
# 8                      Baltic Cup  Klaipeda     Lithuania
# ...

# %%
df[ df['home_score'] > 4]
# Out:
#            date       home_team  away_team  home_score  away_score  \
# 1    1979-07-22         Georgia  Lithuania           5           0
# 23   1993-02-24           Spain  Lithuania           5           0
# 36   1994-05-25  Czech Republic  Lithuania           5           3
# 53   1995-10-11       Lithuania    Estonia           5           0
# 59   1996-08-13         Ukraine  Lithuania           5           2
# 82   1998-06-07         Belarus  Lithuania           5           0
# 105  2000-08-16        Portugal  Lithuania           5           1
# 109  2000-12-22       Catalonia  Lithuania           5           0
# 223  2012-06-01          Latvia  Lithuania           5           0
# 224  2012-06-01          Latvia  Lithuania           5           0
#
#                        tourniment       city         country
# 1                        Friendly     Moscow    Soviet Union
# 23   FIFA World Cup qualification    Seville           Spain
# ...

# %%
import datetime
# df[ df['date'] > datetime.date(2000,1,1) ] # doesn't understand this currently as 'date' is a string. Error

df['date'] = pd.to_datetime(df['date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        367 non-null    datetime64[ns]
#  1   home_team   367 non-null    object
#  2   away_team   367 non-null    object
#  3   home_score  367 non-null    int64
#  4   away_score  367 non-null    int64
#  5   tourniment  367 non-null    object
#  6   city        367 non-null    object
#  7   country     367 non-null    object
# dtypes: datetime64[ns](1), int64(2), object(5)
# memory usage: 23.1+ KB

# %%
df['date'].dt.year
# Out:
# 0      1979
# 1      1979
# 2      1979
# 3      1979
# 4      1979
#        ...
# 362    2019
# 363    2019
# 364    2019
# 365    2019
# 366    2019
# Name: date, Length: 367, dtype: int64

# %%
df[ df['date'].dt.year >= datetime.date(2000,1,1).year ]
# Out:
#           date  home_team  away_team  home_score  away_score  \
# 101 2000-02-02     Cyprus  Lithuania           2           1
# 102 2000-02-04    Moldova  Lithuania           2           1
# 103 2000-02-06     Latvia  Lithuania           1           2
# 104 2000-04-26  Lithuania     Latvia           2           1
# 105 2000-08-16   Portugal  Lithuania           5           1
# ..         ...        ...        ...         ...         ...
# 362 2019-09-10  Lithuania   Portugal           1           5
# 363 2019-10-11    Ukraine  Lithuania           2           0
# 364 2019-10-11    Ukraine  Lithuania           2           0
# 365 2019-10-14  Lithuania     Serbia           1           2
# 366 2019-10-14  Lithuania     Serbia           1           2
#
#                           tourniment      city    country
# 101  Cyprus International Tournament  Limassol     Cyprus
# 102  Cyprus International Tournament   Larnaca     Cyprus
# ...

# %%
df[ df['date'] >= pd.Timestamp(2008,8,1) ]
# Out:
#           date  home_team      away_team  home_score  away_score  \
# 180 2008-08-20  Lithuania        Moldova           3           0
# 181 2008-09-06    Romania      Lithuania           0           3
# 182 2008-09-10  Lithuania        Austria           2           0
# 183 2008-10-11     Serbia      Lithuania           3           0
# 184 2008-10-15  Lithuania  Faroe Islands           1           0
# ..         ...        ...            ...         ...         ...
# 362 2019-09-10  Lithuania       Portugal           1           5
# 363 2019-10-11    Ukraine      Lithuania           2           0
# 364 2019-10-11    Ukraine      Lithuania           2           0
# 365 2019-10-14  Lithuania         Serbia           1           2
# 366 2019-10-14  Lithuania         Serbia           1           2
#
#                        tourniment         city    country
# 180                      Friendly  Marijampol?  Lithuania
# 181  FIFA World Cup qualification         Cluj    Romania
# ...

# %%
df[ df['date'] >= '2008-08-01' ]
# Out:
#           date  home_team      away_team  home_score  away_score  \
# 180 2008-08-20  Lithuania        Moldova           3           0
# 181 2008-09-06    Romania      Lithuania           0           3
# 182 2008-09-10  Lithuania        Austria           2           0
# 183 2008-10-11     Serbia      Lithuania           3           0
# 184 2008-10-15  Lithuania  Faroe Islands           1           0
# ..         ...        ...            ...         ...         ...
# 362 2019-09-10  Lithuania       Portugal           1           5
# 363 2019-10-11    Ukraine      Lithuania           2           0
# 364 2019-10-11    Ukraine      Lithuania           2           0
# 365 2019-10-14  Lithuania         Serbia           1           2
# 366 2019-10-14  Lithuania         Serbia           1           2
#
#                        tourniment         city    country
# 180                      Friendly  Marijampol?  Lithuania
# 181  FIFA World Cup qualification         Cluj    Romania
# ...

# %%
df['home_team'] = pd.Categorical(df['home_team'])
df['away_team'] = pd.Categorical(df['away_team'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        367 non-null    datetime64[ns]
#  1   home_team   367 non-null    category
#  2   away_team   367 non-null    category
#  3   home_score  367 non-null    int64
#  4   away_score  367 non-null    int64
#  5   tourniment  367 non-null    object
#  6   city        367 non-null    object
#  7   country     367 non-null    object
# dtypes: category(2), datetime64[ns](1), int64(2), object(3)
# memory usage: 23.0+ KB

# %%
df[ df['home_team'] == 'Lithuania' ]
# Out:
#           date  home_team away_team  home_score  away_score  \
# 3   1979-07-28  Lithuania   Ukraine           0           2
# 8   1991-11-15  Lithuania   Estonia           4           1
# 9   1991-11-17  Lithuania    Latvia           1           1
# 17  1992-09-02  Lithuania   Georgia           1           0
# 18  1992-09-23  Lithuania   Denmark           0           0
# ..         ...        ...       ...         ...         ...
# 360 2019-09-07  Lithuania   Ukraine           0           3
# 361 2019-09-10  Lithuania  Portugal           1           5
# 362 2019-09-10  Lithuania  Portugal           1           5
# 365 2019-10-14  Lithuania    Serbia           1           2
# 366 2019-10-14  Lithuania    Serbia           1           2
#
#                        tourniment      city       country
# 3                        Friendly    Moscow  Soviet Union
# 8                      Baltic Cup  Klaipeda     Lithuania
# 9                      Baltic Cup  Kretinga     Lithuania
# ...

# %%
len(df)
# Out:
# 367

# %%
df['home_team'] == 'Lithuania'
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 362     True
# 363    False
# 364    False
# 365     True
# 366     True
# Name: home_team, Length: 367, dtype: bool

# %%
df[ df['city'] == 'Kharkiv' ]
# Out:
#           date home_team  away_team  home_score  away_score  \
# 196 2010-05-25   Ukraine  Lithuania           4           0
# 363 2019-10-11   Ukraine  Lithuania           2           0
# 364 2019-10-11   Ukraine  Lithuania           2           0
#
#                   tourniment     city  country
# 196                 Friendly  Kharkiv  Ukraine
# 363  UEFA Euro qualification  Kharkiv  Ukraine
# 364  UEFA Euro qualification  Kharkiv  Ukraine

# %%
df['home_score'] > 2
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 362    False
# 363    False
# 364    False
# 365    False
# 366    False
# Name: home_score, Length: 367, dtype: bool

# %%
df['city'] == 'Vilnius'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 362     True
# 363    False
# 364    False
# 365     True
# 366     True
# Name: city, Length: 367, dtype: bool

# %%
df[ (df['city'] == 'Vilnius') & (df['home_score'] > 2) ]
# Out:
#          date  home_team               away_team  home_score  away_score  \
# 26 1993-04-14  Lithuania                 Albania           3           1
# 37 1994-07-29  Lithuania                 Estonia           3           0
# 53 1995-10-11  Lithuania                 Estonia           5           0
# 64 1996-11-03  Lithuania               Indonesia           4           0
# 90 1998-10-14  Lithuania  Bosnia and Herzegovina           4           2
#
#                       tourniment     city    country
# 26  FIFA World Cup qualification  Vilnius  Lithuania
# 37                    Baltic Cup  Vilnius  Lithuania
# 53       UEFA Euro qualification  Vilnius  Lithuania
# 64                      Friendly  Vilnius  Lithuania
# 90       UEFA Euro qualification  Vilnius  Lithuania

# %%
# Bitwise operators
# and = &
# or = |
# not = ~
# in = .isin( <your_list> )

# %%
# df[ df['city'] == 'Vilnius' & df['home_score'] > 2 ] # error. Put brackets around conditions

# %%
df.loc[ (df['city'].isin( ['Vilnius', 'Kaunas', 'Klaipeda'] ) ), ['home_team', 'away_team', 'home_score', 'away_score'] ]
# Out:
#      home_team away_team  home_score  away_score
# 8    Lithuania   Estonia           4           1
# 17   Lithuania   Georgia           1           0
# 18   Lithuania   Denmark           0           0
# 19   Lithuania  Slovakia           0           1
# 20   Lithuania    Latvia           1           1
# ..         ...       ...         ...         ...
# 360  Lithuania   Ukraine           0           3
# 361  Lithuania  Portugal           1           5
# 362  Lithuania  Portugal           1           5
# 365  Lithuania    Serbia           1           2
# 366  Lithuania    Serbia           1           2
#
# [124 rows x 4 columns]

# %%
df['score_diff'] = df['home_score'] - df['away_score']
df['score_sum'] = df['home_score'] + df['away_score']
df
# Out:
#           date   home_team  away_team  home_score  away_score  \
# 0   1979-07-20  Kyrgyzstan  Lithuania           0           0
# 1   1979-07-22     Georgia  Lithuania           5           0
# 2   1979-07-24  Azerbaijan  Lithuania           0           1
# 3   1979-07-28   Lithuania    Ukraine           0           2
# 4   1979-07-30      Russia  Lithuania           2           0
# ..         ...         ...        ...         ...         ...
# 362 2019-09-10   Lithuania   Portugal           1           5
# 363 2019-10-11     Ukraine  Lithuania           2           0
# 364 2019-10-11     Ukraine  Lithuania           2           0
# 365 2019-10-14   Lithuania     Serbia           1           2
# 366 2019-10-14   Lithuania     Serbia           1           2
#
#                   tourniment     city       country  score_diff  score_sum
# 0                   Friendly   Moscow  Soviet Union           0          0
# ...

# %%
df[ df['home_score'] == df['away_score'] ]
# Out:
#           date         home_team   away_team  home_score  away_score  \
# 0   1979-07-20        Kyrgyzstan   Lithuania           0           0
# 7   1990-05-27           Georgia   Lithuania           2           2
# 9   1991-11-17         Lithuania      Latvia           1           1
# 11  1992-04-28  Northern Ireland   Lithuania           2           2
# 12  1992-05-20           Moldova   Lithuania           1           1
# ..         ...               ...         ...         ...         ...
# 334 2018-06-05         Lithuania      Latvia           1           1
# 353 2019-03-25        Azerbaijan   Lithuania           0           0
# 354 2019-03-25        Azerbaijan   Lithuania           0           0
# 355 2019-06-07         Lithuania  Luxembourg           1           1
# 356 2019-06-07         Lithuania  Luxembourg           1           1
#
#                        tourniment      city           country  score_diff  \
# ...

# %%
df[ df['score_diff'] == 0 ]
# Out:
#           date         home_team   away_team  home_score  away_score  \
# 0   1979-07-20        Kyrgyzstan   Lithuania           0           0
# 7   1990-05-27           Georgia   Lithuania           2           2
# 9   1991-11-17         Lithuania      Latvia           1           1
# 11  1992-04-28  Northern Ireland   Lithuania           2           2
# 12  1992-05-20           Moldova   Lithuania           1           1
# ..         ...               ...         ...         ...         ...
# 334 2018-06-05         Lithuania      Latvia           1           1
# 353 2019-03-25        Azerbaijan   Lithuania           0           0
# 354 2019-03-25        Azerbaijan   Lithuania           0           0
# 355 2019-06-07         Lithuania  Luxembourg           1           1
# 356 2019-06-07         Lithuania  Luxembourg           1           1
#
#                        tourniment      city           country  score_diff  \
# ...

# %%
# Out:
#           date  home_team away_team  home_score  away_score  \
# 3   1979-07-28  Lithuania   Ukraine           0           2
# 8   1991-11-15  Lithuania   Estonia           4           1
# 9   1991-11-17  Lithuania    Latvia           1           1
# 17  1992-09-02  Lithuania   Georgia           1           0
# 18  1992-09-23  Lithuania   Denmark           0           0
# ..         ...        ...       ...         ...         ...
# 360 2019-09-07  Lithuania   Ukraine           0           3
# 361 2019-09-10  Lithuania  Portugal           1           5
# 362 2019-09-10  Lithuania  Portugal           1           5
# 365 2019-10-14  Lithuania    Serbia           1           2
# 366 2019-10-14  Lithuania    Serbia           1           2
#
#                        tourniment      city       country  score_diff  \
# 3                        Friendly    Moscow  Soviet Union          -2
# 8                      Baltic Cup  Klaipeda     Lithuania           3
# ...

# %%
min_score = df['score_diff'].idxmin()
min_row = df.loc[min_score]
min_row
# Out:
# date          1995-05-20 00:00:00
# home_team                 Estonia
# away_team               Lithuania
# home_score                      0
# away_score                      7
# tourniment             Baltic Cup
# city                         Riga
# country                    Latvia
# score_diff                     -7
# score_sum                       7
# Name: 47, dtype: object

# %%
df[ (df['home_team'] == 'Lithuania') ].sort_values('score_diff').iloc[0]
# Out:
#           date  home_team       away_team  home_score  away_score  \
# 108 2000-10-11  Lithuania         Hungary           1           6
# 362 2019-09-10  Lithuania        Portugal           1           5
# 361 2019-09-10  Lithuania        Portugal           1           5
# 98  1999-09-04  Lithuania  Czech Republic           0           4
# 107 2000-10-07  Lithuania         Georgia           0           4
# ..         ...        ...             ...         ...         ...
# 180 2008-08-20  Lithuania         Moldova           3           0
# 85  1998-06-29  Lithuania         Andorra           4           0
# 144 2004-09-08  Lithuania      San Marino           4           0
# 64  1996-11-03  Lithuania       Indonesia           4           0
# 53  1995-10-11  Lithuania         Estonia           5           0
#
#                        tourniment         city    country  score_diff  \
# 108  FIFA World Cup qualification       Kaunas  Lithuania          -5
# ...

# %%
min_val = df[ (df['home_team'] == 'Lithuania') ]['score_diff'].min()
df[ (df['home_team'] == 'Lithuania') ].loc[min_idx]
# Out:
# date                   2000-10-11 00:00:00
# home_team                        Lithuania
# away_team                          Hungary
# home_score                               1
# away_score                               6
# tourniment    FIFA World Cup qualification
# city                                Kaunas
# country                          Lithuania
# score_diff                              -5
# score_sum                                7
# Name: 108, dtype: object
